# %%
import numpy as np
import matplotlib.pyplot as plt

v = np.array([1, 2])
v_R = np.array([-2, 1])

# %%
fig, ax = plt.subplots()
ax.arrow(0, 0, *v, head_width=0.1)
# ... code vẽ tiếp ...
plt.show()
