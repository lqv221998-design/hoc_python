# %% [markdown]
# <span style="color:orange"> 1. Tạo 2 biến a, b. Yêu cầu người dùng nhập từ bàn phím 2 số ngẫu nhiên. Sau đó in ra màn hình kết quả tổng của 2 số vừa nhập.</span>
# #### Chương trình 1: Chương trình đơn giản, kèm xử lý ngoại lệ

# %%
#Sử dụng hàm input, lệnh print, tính tổng, xử lý ngoại lệ:
a = input("Bạn hãy nhập giá trị đầu tiên: ") #Lỗi ValueError khi nhập chữ
b = input("Bạn hãy nhập giá trị thứ hai:")   #Lỗi ValueError khi nhập chữ
try:
    print(f"Tổng hai số là: {int(a) + int(b)}")
except ValueError:
    print("Giá trị bạn nhập không phải là một số nguyên! Hãy thử chạy lại")
# Out:
# Tổng hai số là: 6

# %% [markdown]
# #### Chương trình 2: Chương trình sử dụng vòng lặp cho đến khi người dùng nhập đúng số nguyên

# %%
#Sử dụng While để yêu cầu người dùng nhập đến khi đúng
while True:
    try:
        a = int(input("Bạn hãy nhập giá trị đầu tiên: "))
        b = int(input("Bạn hãy nhập giá trị thứ hai:"))
        print(f"Kết quả là: {a+b}")
        break
    except ValueError:
        print("Hãy nhập số nguyên")
# Out:
# Hãy nhập số nguyên
# Hãy nhập số nguyên
# Kết quả là: 3

# %% [markdown]
# #### Chương trình 3: Giới hạn số lần nhập

# %%
#Sử dụng While để yêu cầu người dùng nhập đến khi đúng, nếu quá 3 lần sẽ thoát chương trình
bo_dem = 0
while True:
    try:
        bo_dem += 1
        if bo_dem > 3:
            print("Bạn đã nhập quá 3 lần, chương trình đã thoát")
            break
        a = int(input("Bạn hãy nhập giá trị đầu tiên: "))
        b = int(input("Bạn hãy nhập giá trị thứ hai:"))
        print(f"Kết quả là: {a+b}, sau {bo_dem} lần thử")
        break
    except ValueError:
        print("Hãy nhập số nguyên")
# Out:
# Kết quả là: 3, sau 1 lần thử

# %% [markdown]
# <span style="color:orange">2. Tạo 2 biến a và b. Yêu cầu người dùng nhập vào từ bàn phím 2 số ngẫu nhiên. Kiểm tra a có chia hết cho b hay không? Nếu có, in ra màn hình dòng chữ  “a chia het cho b”, ngược lại, in ra dòng chữ “ a khong chia het cho b” (nhập b khác 0)
# #### Cách 1 đơn giản, xử lý ngoại lệ

# %%
try:
    a = float(input("Nhập số a: "))
    b = float(input("Nhập số b: "))
    if a % b == 0:
        print('a chia hết cho b')
    else:
        print("a không chia hết cho b")
except ZeroDivisionError:
    print("Nhập b khác 0")
except ValueError:
    print("Bạn phải nhập một số thực")
# Out:
# Bạn phải nhập số thực

# %% [markdown]
# #### cách 2: Vòng lặp yêu cầu người dùng nhập đến khi đúng

# %%
while True:
    try:
        a = float(input("Nhập số a: "))
        b = float(input("Nhập số b: "))
        if a % b == 0:
            print('a chia hết cho b')
        else:
            print("a không chia hết cho b")
        break
    except ZeroDivisionError:
        print("Nhập b khác 0")
    except ValueError:
        print("Bạn phải nhập một số thực")
# Out:
# Nhập b khác 0
# Nhập b khác 0
# a không chia hết cho b

# %% [markdown]
# #### Cách 3: giới hạn số lần nhập 2 lần

# %%
bo_dem = 0
while True:
    try:
        bo_dem += 1
        if bo_dem > 2:
            print("Đã hết số lần nhập")
            break
        a = float(input("Nhập số a: "))
        b = float(input("Nhập số b: "))
        if a % b == 0:
            print('a chia hết cho b')
        else:
            print("a không chia hết cho b")
        break
    except ZeroDivisionError:
        print("Nhập b khác 0")
    except ValueError:
        print("Bạn phải nhập một số thực")
# Out:
# Bạn phải nhập một số thực
# Bạn phải nhập một số thực
# Đã hết số lần nhập

# %% [markdown]
# <span style="color:orange">3. Tạo biến year yêu cầu người dùng nhập vào 1 số (giả sử người dùng luôn nhập số > 0 ). Hãy kiểm tra year và in ra màn hình năm đó có phải là năm nhuận hay không?
# #### Cách 1 code chay

# %%
# Logic: 
# Có 2 trường hợp cần phải xét:
# Năm không thế kỷ: năm đó chia hết cho 4
# Năm tròn thế kỷ (có 2 số 00 ở cuối ví dụ 2000): chia hết cho 400
try:
    year = input("Nhập năm")
    if year[2:]=='00':  #dùng slicing
        tinh = year % 400
        if tinh == 0:
            print(f"{year} là năm nhuận")
        else:
            print(f"{year} không phải là năm nhuận")
    elif int(year) == 0:
        print("bạn phải nhập năm khác 0")
    else:
        tinh = int(year) % 4
        if tinh == 0:
            print(f"{year} là năm nhuận")
        else:
            print(f"{year} không phải là năm nhuận")
except TypeError:
    print("Bạn phải nhập số lớn hơn 0")
except ValueError:
    print(f"{year} không phải là năm")
# Out:
# 2021 không phải là năm nhuận

# %% [markdown]
# #### Cách 2 sử dụng thư viện

# %%
import calendar as cl
def Tinh_năm_Nhuan(year):
    if cl.isleap(year) == True:
        return f"{year} là năm nhuận"
    else:
        return f"{year} không phải là năm nhuận"
try:
    year = int(input("Nhập năm"))
    print(Tinh_năm_Nhuan(year))
except:
    print("Nhập số nguyên")
# Out:
# Nhập số nguyên

# %% [markdown]
# <span style="color:orange">4. Tạo 1 danh sách có 5 số. Sau đó tạo 2 biến x, y lưu trữ 2 số được nhập vào từ bàn phím. Chèn x vào vị trí thứ 2 trong danh sách, y vào trị trí cuối cùng trong danh sách.

# %%
list_number = [2,3,4,5,7]
x = int(input("nhập giá trị x: "))
y = int(input("Nhập giá trị y: "))
list_number.insert(2,x)
list_number.append(y)
print(list_number)
# Out:
# [2, 3, 2, 4, 5, 7, 3]

# %% [markdown]
# <span style="color:orange">5. Cho sẵn cao = 3 và rong = 2. Nếu diện tích < 10 thì in “bé”, còn lại in “đạt”.

# %%
# Giả sử tính diện tích hình chữ nhật
cao = 3
rong = 2
dien_tich = 3*2
if dien_tich < 10:
    print("bé")
else:
    print("đạt")
# Out:
# bé

# %% [markdown]
# <span style="color:orange">6.  Viết chương trình kiểm tra xem tải trọng của dầm có vượt quá giới hạn 5000 kg không

# %%
gioi_han = 5000
def kiem_tra_tai_trong(tai_trong_dam):
    if tai_trong_dam < gioi_han:
        return "Dầm đạt"
    else:
        return "Dầm vượt tải trọng"
try:
    tai_trong_dam = float(input("nhập tải trọng dầm"))
    print(kiem_tra_tai_trong(tai_trong_dam))
except ValueError:
    print("Nhập số thực")
# Out:
# Dầm đạt

# %% [markdown]
# <span style="color:orange">7. Tạo biến s lưu trữ kết quả mà người dùng nhập vào từ bàn phím. Kiểm tra xem trong a các ký tự đặc biệt không?  Nếu có, in ra màn hình dòng chữ ‘Yes’, ngược lại in ra dòng chữ ‘No’, biết rằng, ký tự đặc biệt là các ký tự !, @, #, $, ^

# %%
s = input("Hãy nhập giá trị")
if s.isalnum() == True:
    print("No")
else:
    print("Yes")
# Out:
# Yes

# %% [markdown]
# <span style="color:orange">8.Tạo 3 biến lưu trữ 3 số do người dùng nhập vào từ bàn phím. Kiểm tra xem 3 giá trị vừa nhập phải là độ dài của 1 tam giác hay không? (Gợi ý: Sử dụng bất đẳng thức tam giác để làm bài 6)

# %%
try:
    a = float(input("nhập a: ")) 
    b = float(input("nhập b: ")) 
    c = float(input("nhập c: ")) 
    if (a + b > c) and (a + c > b) and (b + c > a) and (a > 0, b > 0, c > 0):
        print("Ba giá trị vừa nhập là độ dài của 1 tam giác")
    else:
        print("không phải độ dài 1 tam giác")
except ValueError:
    print("Giá trị không hợp lệ")
# Out:
# Giá trị không hợp lệ

# %% [markdown]
# <span style="color:orange">9. Viết chương trình cho phép nhập hai cạnh của tam giác vuông (a,b), sau đó tính cạnh huyền và in kết quả (làm tròn 2 chữ số).

# %%
import math
try:
    a = float(input("nhập a: ")) 
    b = float(input("nhập b: ")) 
    if a <= 0 or b <= 0:
        print("nhập số lớn hơn 0")
    else:
        c = math.sqrt(math.pow(a,2) + math.pow(b,2))
        print(round(c,2))
except ValueError:
    print("Hãy nhập một số")
# Out:
# 7.81

# %% [markdown]
# <span style="color:orange">10. Nhập một mã công trình từ bàn phím (có thể người dùng nhập thường, ví dụ ct01, Ct02).

# %% [markdown]
# Yêu cầu:
# Loại bỏ khoảng trắng hai đầu
# Chuyển sang chữ hoa
# In ra dạng: Mã chuẩn hóa: CT01

# %%
#Khai báo hàm
def ma_chuan_hoa (ma_du_an=""):
    return ma_du_an.strip().upper()
#Lấy dữ liệu
ma = input("Nhập mã dự án")
print(ma_chuan_hoa(ma)) #Kết qủa
# Out:
# CT1,CT2

# %% [markdown]
# Bài tập 3: Nhập vào lần lượt 3 hệ số a, b, c của phương trình bậc 2 (ax^2+bx+c = 0). Giải phương trình bậc 2 trên và in nghiệm ra màn hình.

# %%
import math
def tinh_phuong_trinh_bac_2(a,b,c):
    delta = math.pow(b,2)-4*a*c
    if delta < 0:
        return f"Phương trình vô nghiệm"
    elif delta == 0:
        x = -b/2*a
        return "Phương trình có nghiệm kép"
    else:
        x1 = (-b + math.sqrt(delta))/2*a
        x2 = (-b - math.sqrt(delta))/2*a
        return f"Phương trình có nghiệm 1:{x1}, nghiệm 2:{x2}"
try:
    a = int(input("Nhập số a: "))
    b = int(input("Nhập số b: "))
    c = int(input("Nhập số c: "))
    print(tinh_phuong_trinh_bac_2(a,b,c))
except ValueError:
    print("Hãy nhập số")

# %% [markdown]
# Câu 2: Hãy sử dụng Python để giải bài toán cổ sau : “ Vừa gà vừa chó, Bó lại cho tròn, Ba mươi sáu con, Một trăm chân chẵn “

# %% [markdown]
# Tạo 3 biến lưu trữ 3 giá trị nhập vào ngày tháng năm, in ra ngày hôm sau và ngày hôm qua của ngày vừa nhập
