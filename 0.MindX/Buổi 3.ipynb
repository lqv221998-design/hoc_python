# %%
# !pip3 install numpy

# %%
# !pip3 install pandas

# %%
import numpy as np
mang = np.array([1,2,3]) + 1
print(mang)
# Out:
# [2 3 4]

# %%
print(np.linspace(2,10,4))
# Out:
# [ 2.          4.66666667  7.33333333 10.        ]

# %%
np.random.randn(5,2)
# Out:
# array([[ 0.08850924, -1.60955477],
#        [-1.02184275,  0.1829413 ],
#        [ 0.68550255, -0.03389109],
#        [-1.0233901 ,  0.31369207],
#        [ 0.73973446, -0.70524075]])

# %%
array = np.array([[1,2,3],[4,5,6]])
print(np.argmax(array))
# Out:
# 5

# %%
import pandas as pd

# %%
# tạo data frame từ danh sách dữ liệu:

data = {'Name': ['An', 'Binh', 'Chi', 'Dung', 'Em'],
        'Age': [23, 25, 22, 24, 23],
        'City': ['Hanoi', 'Saigon', 'Danang', 'Hue', 'Nha Trang']}
pd.DataFrame(data, columns=['Name', 'Age', 'City'])
# Out:
#    Name  Age       City
# 0    An   23      Hanoi
# 1  Binh   25     Saigon
# 2   Chi   22     Danang
# 3  Dung   24        Hue
# 4    Em   23  Nha Trang

# %% [markdown]
# # Thống kê

# %%
# thống kê cơ bản
